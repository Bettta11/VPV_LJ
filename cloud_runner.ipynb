# %% [markdown]
# # VPV_LJ runner
#
# Stage 1 keeps this notebook intentionally thin. Full orchestration is scheduled for stage 4.

# %%
from debug import run_debug

debug_dir = run_debug('configs/debug.yaml')
debug_dir
